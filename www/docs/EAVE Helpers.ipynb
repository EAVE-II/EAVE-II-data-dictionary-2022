# %% [markdown]
# ## Install
#
# To install the helper package, install `remotes` and then install directly from GitHub like so:

# %%
remotes::install_github("EAVE-II/eavehelpers")
# Out:
# Downloading GitHub repo EAVE-II/eavehelpers@HEAD
# ✔  checking for file ‘/private/var/folders/1_/t4xb4ssn55v6wrkx8x5rzkqc0000gn/T/RtmpZROikZ/remotese90735356bd5/EAVE-II-eavehelpers-1bfb2ae/DESCRIPTION’
# ─  preparing ‘eavehelpers’:
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building ‘eavehelpers_0.0.1.tar.gz’
# Installing package into ‘/usr/local/lib/R/4.2/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# ## Data Dictionary
#
# Look up labels and descriptions of variables in the EAVE-II datasets:

# %%
eavehelpers::get_label('Q_DIAG_COPD')
# Out:
# [1] "Chronic obstructive pulmonary disease (COPD) indicator"

# %%
eavehelpers::get_description('Q_DIAG_COPD')
# Out:
# [1] "Study marked as at risk of COVID-19 due to Chronic obstructive pulmonary disease (COPD) indicator"

# %% [markdown]
# Get the full data dictionary if you want to explore more / lookup more data

# %%
dd <- eavehelpers::get_data_dictionary()
dd
# Out:
#     name                      label
# 1   EAVE_LINKNO               EAVE Study Identifier
# 2   SampleID                  Sample ID
# 3   age                       Age
# 4   sex                       Sex (number)
# 5   isoweek                   Week Number
# 6   year                      Year
# 7   Sampledate_iso            Sample Date
# 8   hb                        Health Board
# 9   assay                     Assay
# 10  test_result_qual          Qualitative Test Result
# 11  test_result_quant         Quantative Test Result
# 12  EAVE_LINKNO               EAVE Study Identifier
# 13  CIS_MARKER
# 14  ADMISSION_DATE            Admission Date
# 15  DISCHARGE_DATE            Discharge Date
# 16  MAIN_CONDITION            Main Condition
# 17  OTHER_CONDITION_1
# 18  OTHER_CONDITION_2
# 19  OTHER_CONDITION_3
# 20  OTHER_CONDITION_4
# 21  OTHER_CONDITION_5
# 22  EAVE_LINKNO               EAVE Study Identifier
# 23  Sex                       Sex
# 24  ageYear                   Age
# 25  hb2019                    NHS Health Board Code
# 26  hb2019name                NHS Health Board Name
# 27  District                  Postcode District
# 28  DataZone                  Data Zone
# 29  ur6_2016                  Urban/Rural classification
# 30  ur6_2016_name             Urban/Rural classification name
# ⋮   ⋮                         ⋮
# 204 SpecimenTypeRaw           Specimen Type Raw
# 205 SpecimenType              Specimen Type
# 206 SpecLevel2Group
# 207 SpecLevel1Group
# 208 OrganismRaw               Organism Raw
# 209 Type                      Type
# 210 OriginalOrganism          Original organism
# 211 test_result_qual          Qualitative Test Result
# 212 test_result_quant         Quantative Test Result
# 213 QNum                      Quantative Measumrent Value (Number)
# 214 Text                      Text
# 215 EAVE_LINKNO               EAVE Study Identifier
# 216 NRS.Date.Death            Date of NRS death record
# 217 NRS.Reg.Date              Date of death registered
# 218 NRS.Reg.Dist
# 219 NRS.Entry
# 220 NRS.Reg.Year
# 221 NRS.age_at_death
# 222 UNDERLYING_CAUSE_OF_DEATH
# 223 CAUSE_OF_DEATH_CODE_0
# 224 CAUSE_OF_DEATH_CODE_1
# 225 CAUSE_OF_DEATH_CODE_2
# 226 CAUSE_OF_DEATH_CODE_3
# 227 CAUSE_OF_DEATH_CODE_4
# 228 CAUSE_OF_DEATH_CODE_5
# 229 CAUSE_OF_DEATH_CODE_6
# 230 CAUSE_OF_DEATH_CODE_7
# 231 CAUSE_OF_DEATH_CODE_8
# 232 CAUSE_OF_DEATH_CODE_9
# 233 source
#     description
# 1   EAVE-II Identifier, pseudoynmised CHI numbers are used to create randomly assigned study index numbers.
# 2   Original Sample ID from the serology team
# 3   Age of the study given in years, extracted from the serology files - and shouldn't be well trusted
# 4   Sex at birth - extracted from the serology files/team - it should not be trusted as being reliable
# 5   Week number since the start of the pandemic
# 6   Year of the lookup file used to determine the Health Boards
# 7   The date the serology measurement was taken from the individual (in ISO format)
# 8   The Scottish Health Board in which the individual was registered with
# 9   Antibody Assay machine was was used when measuring the blood serum sample for the presence of IgG antibodies to SARs-CoV-2
# 10  Qualitative test results from the assay for the presence (or lack thereof) of IgG to SARs-CoV-2. The assay defines the threshold that determines +ve or -ve tests.
# 11  IgG measurements in Binding Activation Units [BAUs] that are measured by the assay. There are values that are truncated above/below certain values as the result was out-of-bounds of the assay's sensitivity for these.
# 12  EAVE-II Identifier, pseudoynmised CHI numbers that were used to link this dataset
# 13
# 14  Date the study was admitted into hospital
# 15  Date the study was discharged from hospital
# 16  The reason the study was admitted into hospital (ICD10 code)
# 17  Other reasons identified for hospital admission (ICD10 codes)
# 18  Other reasons identified for hospital admission
# 19  Other reasons identified for hospital admission
# 20  Other reasons identified for hospital admission
# 21  Other reasons identified for hospital admission
# 22  EAVE-II Identifier, pseudoynmised CHI numbers are used to create randomly assigned study index numbers.
# 23  Sex at birth
# 24  Age in years
# 25  Codes of 2019 NHS Health Boards
# 26  Names of 2019 NHS Health Boards
# 27  Outward code of their postcode (Area + Disrict)
# 28  Data Zone
# 29  Urban/Rural 6-fold classification (2016 classification)
# 30  Urban/Rural 6-fold classification (2016 classification)
# ⋮   ⋮
# 204 Raw code for the specimen type (always STS as this is blood serum data)
# 205 Always 'Serum' as this is serology dataset
# 206
# 207
# 208 Raw data of the test result from the assay
# 209 Type of measurement (almost always IgG 2019-nCoV)
# 210 Original organism - Coronavirus 2019 positive or negative
# 211 Qualitative test results from the assay for the presence (or lack thereof) of IgG to SARs-CoV-2. The assay defines the threshold that determines +ve or -ve tests.
# 212 IgG measurements in Binding Activation Units [BAUs] that are measured by the assay. There are values that are truncated above/below certain values as the result was out-of-bounds of the assay's sensitivity for these.
# 213 The raw quantative number value, removing truncated values (note: not so safe to use this as values below AND above the assay threshold have been set as NA
# 214 Raw text output from the final report
# 215 EAVE-II Identifier, pseudoynmised CHI numbers are used to create randomly assigned study index numbers.
# 216 Date of death
# 217 Date of death registered
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
#     type min  max
# 1   chr
# 2   chr
# 3   dbl  17   84
# 4   chr
# 5   dbl  1    53
# 6   dbl  2020 2022
# 7   dttm
# 8   chr
# 9   chr
# 10  chr
# 11  chr
# 12  chr
# 13  dbl  1    1906
# 14  dttm
# 15  dttm
# 16  chr
# 17  chr
# 18  chr
# 19  chr
# 20  chr
# 21  chr
# 22  chr
# 23  chr
# 24  dbl  -1   111
# 25  chr
# 26  chr
# 27  chr
# 28  chr
# 29  int  NA   NA
# 30  chr
# ⋮   ⋮    ⋮    ⋮
# 204 chr
# 205 chr
# 206 chr
# 207 chr
# 208 chr
# 209 chr
# 210 chr
# 211 chr
# 212 chr
# 213 dbl  NA   NA
# 214 chr
# 215 chr
# 216 date
# 217 date
# 218 dbl  118  875
# 219 dbl  1    999
# 220 dbl  2020 2022
# 221 dbl  0    106
# 222 chr
# 223 chr
# 224 chr
# 225 chr
# 226 chr
# 227 chr
# 228 chr
# 229 chr
# 230 chr
# 231 chr
# 232 chr
# 233 chr
#     values
# 1   NULL
# 2   NULL
# 3   57, 55, 56, 54, 52
# 4   F, M
# 5   28, 36, 32, 41, 51
# 6   2021, 2020, 2022
# 7   2021-12-20, 2020-07-02, 2021-12-30, 2020-07-06, 2022-01-14
# 8   NHS Lothian                  , NHS Greater Glasgow and Clyde, NHS Tayside                  , NHS Grampian                 , NHS Lanarkshire
# 9   Euroimmune, Abbott
# 10  Positive , Negative , Equivocal
# 11  0.1 , 0.02, 0.2 , 0.01, 0.03
# 12  NULL
# 13  2, 3, 4, 1, 6
# 14  2019-06-11, 2019-08-12, 2018-03-07, 2018-06-05, 2019-03-04
# 15  2019-06-18, 2019-03-04, 2019-08-12, 2019-08-30, 2020-01-17
# 16  H269, N390, U071, A419, J22X
# 17  NA  , Z511, N390, I10X, N179
# 18  NA  , I10X, E119, I489, Z511
# 19  NA  , I10X, E119, I489, N179
# 20  NA  , I10X, E119, I489, Z867
# 21  NA  , I10X, E119, Z038, Z867
# 22  NULL
# 23  M, F
# 24  51, 26, 50, 55, 27
# ...
# 219 11, 8 , 35, 4 , 51
# 220 2020, 2021, 2022
# 221 84, 85, 83, 87, 90
# 222 U071, I219, C349, F03 , G301
# 223 R688, C349, J189, F019, I259
# 224 NA  , I259, U071, R688, I489
# 225 NA  , E119, I259, J449, I10
# 226 NA  , J449, E119, I10 , I259
# 227 NA  , J449, E119, N189, I10
# 228 NA  , I10 , J449, W19 , E119
# 229 NA  , I10 , T424, N189, T403
# 230 NA  , T424
# 231 NULL
# 232 NULL
# 233 SMRA , daily
